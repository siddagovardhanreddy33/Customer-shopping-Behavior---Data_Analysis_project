# %% [markdown]
# ## Customer Shopping Behavior Analysis for Business Insights

# %% [markdown]
# ### Problem Statement:
#
# - A retail business wants to better understand its customers' purchasing behavior to improve sales, optimize marketing strategies, and enhance customer satisfaction. The company has collected transactional and behavioral data, but lacks clear insights.
#
# - The goal of this project is to analyze customer shopping data to identify patterns, trends, and factors that influence purchasing decisions.

# %% [markdown]
# ### importing libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Loading dataset

# %%
df = pd.read_csv("customer_shopping_behavior.csv")

# %% [markdown]
# ### Basic data Overview

# %%
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0            2701   22  Female        T-shirt     Clothing
# 1             521   51    Male     Sunglasses  Accessories
# 2            3157   18  Female          Shirt     Clothing
# 3            1687   22    Male         Gloves  Accessories
# 4            2929   40  Female        Jewelry  Accessories
# ...           ...  ...     ...            ...          ...
# 5045          913   24    Male         Hoodie     Clothing
# 5046         3466   19  Female       Backpack  Accessories
# 5047         3572   70  Female          Skirt     Clothing
# 5048         3195   43  Female       Sneakers     Footwear
# 5049         1832   62    Male         Blouse     Clothing
#
#       Purchase Amount (USD)        Location Size   Color  Season  \
# 0                      68.0      California   XL   Olive  Winter
# 1                      84.0  South Carolina    M   White  Spring
# 2                      50.0         Montana    M   Black  Winter
# 3                      75.0        Illinois    L     Red    Fall
# 4                      80.0         Alabama    L  Yellow  Spring
# ...                     ...             ...  ...     ...     ...
# 5045                   56.0        Arkansas    M   Green  Winter
# 5046                   53.0            Iowa    M    Gold  Spring
# 5047                   27.0    North Dakota    M   White  Summer
# 5048                   52.0        Maryland    L    Gold  Summer
# 5049                   71.0           Maine    M    Cyan  Summer
#
#       Review Rating Subscription Status   Shipping Type Discount Applied  \
# 0               3.2                  No        Standard               No
# 1               3.9                 Yes   Free Shipping              Yes
# 2               3.1                  No  2-Day Shipping               No
# 3               4.2                  No    Store Pickup               No
# 4               3.6                  No    Store Pickup               No
# ...             ...                 ...             ...              ...
# 5045            3.4                 Yes    Next Day Air              Yes
# 5046            3.4                  No        Standard               No
# 5047            3.2                  No        Standard               No
# 5048            4.6                  No        Standard               No
# 5049            3.3                  No   Free Shipping               No
#
#       Previous Purchases Payment Method Frequency of Purchases
# 0                   36.0           Cash                 Weekly
# 1                   20.0     Debit Card              Quarterly
# 2                   18.0           Cash                Monthly
# 3                   25.0           Cash               Annually
# 4                   17.0    Credit Card                 Weekly
# ...                  ...            ...                    ...
# 5045                32.0  Bank Transfer                Monthly
# 5046                31.0     Debit Card                 Weekly
# 5047                15.0  Bank Transfer         Every 3 Months
# 5048                10.0    Credit Card              Bi-Weekly
# 5049                 5.0  Bank Transfer         Every 3 Months
#
# [5050 rows x 17 columns]

# %%
df.head()
# Out:
#    Customer ID  Age  Gender Item Purchased     Category  \
# 0         2701   22  Female        T-shirt     Clothing
# 1          521   51    Male     Sunglasses  Accessories
# 2         3157   18  Female          Shirt     Clothing
# 3         1687   22    Male         Gloves  Accessories
# 4         2929   40  Female        Jewelry  Accessories
#
#    Purchase Amount (USD)        Location Size   Color  Season  Review Rating  \
# 0                   68.0      California   XL   Olive  Winter            3.2
# 1                   84.0  South Carolina    M   White  Spring            3.9
# 2                   50.0         Montana    M   Black  Winter            3.1
# 3                   75.0        Illinois    L     Red    Fall            4.2
# 4                   80.0         Alabama    L  Yellow  Spring            3.6
#
#   Subscription Status   Shipping Type Discount Applied  Previous Purchases  \
# 0                  No        Standard               No                36.0
# 1                 Yes   Free Shipping              Yes                20.0
# 2                  No  2-Day Shipping               No                18.0
# 3                  No    Store Pickup               No                25.0
# 4                  No    Store Pickup               No                17.0
#
#   Payment Method Frequency of Purchases
# 0           Cash                 Weekly
# 1     Debit Card              Quarterly
# 2           Cash                Monthly
# 3           Cash               Annually
# 4    Credit Card                 Weekly

# %%
df.tail()
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 5045          913   24    Male         Hoodie     Clothing
# 5046         3466   19  Female       Backpack  Accessories
# 5047         3572   70  Female          Skirt     Clothing
# 5048         3195   43  Female       Sneakers     Footwear
# 5049         1832   62    Male         Blouse     Clothing
#
#       Purchase Amount (USD)      Location Size  Color  Season  Review Rating  \
# 5045                   56.0      Arkansas    M  Green  Winter            3.4
# 5046                   53.0          Iowa    M   Gold  Spring            3.4
# 5047                   27.0  North Dakota    M  White  Summer            3.2
# 5048                   52.0      Maryland    L   Gold  Summer            4.6
# 5049                   71.0         Maine    M   Cyan  Summer            3.3
#
#      Subscription Status  Shipping Type Discount Applied  Previous Purchases  \
# 5045                 Yes   Next Day Air              Yes                32.0
# 5046                  No       Standard               No                31.0
# 5047                  No       Standard               No                15.0
# 5048                  No       Standard               No                10.0
# 5049                  No  Free Shipping               No                 5.0
#
#      Payment Method Frequency of Purchases
# 5045  Bank Transfer                Monthly
# 5046     Debit Card                 Weekly
# 5047  Bank Transfer         Every 3 Months
# 5048    Credit Card              Bi-Weekly
# 5049  Bank Transfer         Every 3 Months

# %%
df.sample(7)
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 1139         3760   44  Female       Sneakers     Footwear
# 90           1837   66    Male          Pants     Clothing
# 25           1612   41    Male          Pants     Clothing
# 4143           75   49    Male         Gloves  Accessories
# 2538         4453   24  Female          Shoes     Clothing
# 4519         2905   41  Female        Sandals     Footwear
# 2364         4371   67   Other          Shoes     Clothing
#
#       Purchase Amount (USD)        Location Size   Color  Season  \
# 1139                  61.00        Missouri    M    Pink  Spring
# 90                    52.00  South Carolina    M    Teal    Fall
# 25                    26.00        Arkansas    L  Yellow  Winter
# 4143                  58.00         Indiana    L  Violet  Spring
# 2538                    NaN         Houston    M   Green  Summer
# 4519                  41.00            Iowa    M    Gray  Spring
# 2364                 617.37         Houston    L   Black  Winter
#
#       Review Rating Subscription Status   Shipping Type Discount Applied  \
# 1139            3.5                  No    Store Pickup               No
# 90              4.2                  No  2-Day Shipping               No
# 25              4.5                  No    Next Day Air              Yes
# 4143            4.5                 Yes         Express              Yes
# 2538            NaN                 Yes         Express              Yes
# 4519            4.0                  No  2-Day Shipping               No
# 2364            3.0                  No         Express              Yes
#
#       Previous Purchases Payment Method Frequency of Purchases
# 1139                30.0          Venmo              Quarterly
# 90                  35.0    Credit Card                Monthly
# 25                   6.0     Debit Card                Monthly
# 4143                 3.0           Cash                Monthly
# 2538                47.0           Cash                Monthly
# 4519                43.0          Venmo                Monthly
# 2364                 0.0     Debit Card              Quarterly

# %% [markdown]
# ### Shape of data

# %%
df.shape
# Out:
# (5050, 17)

# %% [markdown]
# ### column names

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Previous Purchases', 'Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %% [markdown]
# ### data info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5050 entries, 0 to 5049
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             5050 non-null   int64
#  1   Age                     5050 non-null   int64
#  2   Gender                  5050 non-null   object
#  3   Item Purchased          5050 non-null   object
#  4   Category                5050 non-null   object
#  5   Purchase Amount (USD)   4494 non-null   float64
#  6   Location                5050 non-null   object
#  7   Size                    4680 non-null   object
#  8   Color                   5050 non-null   object
#  9   Season                  5050 non-null   object
#  10  Review Rating           4449 non-null   float64
#  11  Subscription Status     5050 non-null   object
#  12  Shipping Type           5050 non-null   object
#  13  Discount Applied        5050 non-null   object
#  14  Previous Purchases      4502 non-null   float64
#  15  Payment Method          5050 non-null   object
#  16  Frequency of Purchases  5050 non-null   object
# dtypes: float64(3), int64(2), object(12)
# memory usage: 670.8+ KB

# %% [markdown]
# ### Checking  null values

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)     556
# Location                    0
# Size                      370
# Color                       0
# Season                      0
# Review Rating             601
# Subscription Status         0
# Shipping Type               0
# Discount Applied            0
# Previous Purchases        548
# Payment Method              0
# Frequency of Purchases      0
# dtype: int64

# %% [markdown]
# ### Checking Duplicates

# %%
df.duplicated().sum()
# Out:
# 50

# %% [markdown]
# ### Statistical Summary

# %%
df.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  5050.000000  5050.000000            4494.000000    4449.000000
# mean   2519.570891    44.150495             144.765236       3.668195
# std    1470.402964    15.282328             275.590101       0.865357
# min       1.000000    18.000000              10.120000       1.000000
# 25%    1252.250000    31.000000              41.000000       3.000000
# 50%    2499.500000    44.000000              65.000000       3.700000
# 75%    3740.750000    57.000000              89.000000       4.400000
# max    5099.000000    70.000000            1499.760000       5.000000
#
#        Previous Purchases
# count         4502.000000
# mean            25.221901
# std             14.521635
# min              0.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %% [markdown]
# ### Understand Each Column

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Previous Purchases', 'Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %%
df['Age'].unique()
# Out:
# array([22, 51, 18, 40, 23, 62, 61, 37, 42, 35, 46, 64, 57, 68, 56, 52, 30,
#        21, 70, 58, 33, 60, 41, 34, 66, 38, 49, 69, 67, 24, 65, 43, 39, 59,
#        53, 47, 36, 20, 44, 55, 26, 29, 50, 19, 27, 48, 45, 63, 25, 31, 28,
#        32, 54], dtype=int64)

# %%
df['Age'].value_counts()
# Out:
# Age
# 41    114
# 57    111
# 69    110
# 54    109
# 25    107
# 46    104
# 28    104
# 59    104
# 49    104
# 23    104
# 27    103
# 29    103
# 42    102
# 31    101
# 66    101
# 62    100
# 65    100
# 32    100
# 50    100
# 58     98
# 63     98
# 19     98
# 53     97
# 56     96
# 37     96
# 60     96
# 55     95
# 43     94
# 20     94
# 70     94
# 40     93
# 68     93
# 36     92
# 38     91
# 18     91
# 52     91
# 47     91
# 35     90
# 34     90
# 51     89
# 45     89
# 64     89
# 22     88
# 39     87
# 61     87
# 26     86
# 24     86
# 48     85
# 33     84
# 30     84
# 21     83
# 44     79
# 67     75
# Name: count, dtype: int64

# %%
df['Age'].describe()
# Out:
# count    5050.000000
# mean       44.150495
# std        15.282328
# min        18.000000
# 25%        31.000000
# 50%        44.000000
# 75%        57.000000
# max        70.000000
# Name: Age, dtype: float64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      3018
# Female    1670
# Other      362
# Name: count, dtype: int64

# %%
df['Category'].value_counts()
# Out:
# Category
# Clothing       2130
# Accessories    1615
# Footwear        607
# Electronics     370
# Outerwear       328
# Name: count, dtype: int64

# %%
df['Item Purchased'].unique()
# Out:
# array(['T-shirt', 'Sunglasses', 'Shirt', 'Gloves', 'Jewelry', 'Shorts',
#        'Hat', 'Handbag', 'Shoes', 'Coat', 'Laptop', 'Hoodie', 'Phone',
#        'Jacket', 'Pants', 'Backpack', 'Socks', 'Jeans', 'Bag', 'Belt',
#        'Watch', 'Headphones', 'Blouse', 'Sandals', 'Skirt', 'Sweater',
#        'Scarf', 'Sneakers', 'Boots', 'Dress'], dtype=object)

# %%
df['Item Purchased'].value_counts()
# Out:
# Item Purchased
# Shirt         320
# Shoes         306
# Jewelry       174
# Blouse        172
# Pants         171
# Phone         171
# Sweater       166
# Headphones    166
# Jacket        166
# Dress         166
# Sunglasses    164
# Bag           164
# Belt          164
# Sandals       163
# Shorts        163
# Coat          162
# Socks         159
# Skirt         159
# Scarf         159
# Handbag       157
# Watch         157
# Hat           155
# Hoodie        151
# T-shirt       150
# Boots         146
# Sneakers      145
# Backpack      144
# Laptop        143
# Gloves        140
# Jeans         127
# Name: count, dtype: int64

# %%
df['Purchase Amount (USD)'].describe()
# Out:
# count    4494.000000
# mean      144.765236
# std       275.590101
# min        10.120000
# 25%        41.000000
# 50%        65.000000
# 75%        89.000000
# max      1499.760000
# Name: Purchase Amount (USD), dtype: float64

# %%
df['Discount Applied'].value_counts()
# Out:
# Discount Applied
# No     2789
# Yes    2261
# Name: count, dtype: int64

# %%
df['Review Rating'].describe()
# Out:
# count    4449.000000
# mean        3.668195
# std         0.865357
# min         1.000000
# 25%         3.000000
# 50%         3.700000
# 75%         4.400000
# max         5.000000
# Name: Review Rating, dtype: float64

# %%
df['Frequency of Purchases'].value_counts()
# Out:
# Frequency of Purchases
# Monthly           946
# Quarterly         933
# Weekly            894
# Every 3 Months    592
# Annually          581
# Bi-Weekly         556
# Fortnightly       548
# Name: count, dtype: int64

# %%
df.Location.unique()
# Out:
# array(['California', 'South Carolina', 'Montana', 'Illinois', 'Alabama',
#        'Wisconsin', 'Tennessee', 'Florida', 'Kentucky', 'Phoenix',
#        'Pennsylvania', 'Los Angeles', 'Vermont', 'North Dakota', 'Ohio',
#        'Colorado', 'Maine', 'Massachusetts', 'Arkansas', 'New York',
#        'Indiana', 'Maryland', 'New Mexico', 'Michigan', 'Connecticut',
#        'Louisiana', 'Minnesota', 'Oregon', 'Kansas', 'Houston',
#        'South Dakota', 'New Jersey', 'New Hampshire', 'North Carolina',
#        'Hawaii', 'Nebraska', 'Virginia', 'Chicago', 'Iowa', 'Oklahoma',
#        'Delaware', 'Utah', 'Missouri', 'Alaska', 'Mississippi', 'Arizona',
#        'Texas', 'West Virginia', 'Washington', 'Nevada', 'Rhode Island',
#        'Georgia', 'Idaho', 'Wyoming'], dtype=object)

# %%
df['Location'].value_counts()
# Out:
# Location
# New York          337
# Los Angeles       236
# Houston           210
# Phoenix           208
# Chicago           196
# Montana            97
# Idaho              96
# California         96
# Illinois           94
# Nebraska           90
# Minnesota          90
# Alabama            90
# Nevada             88
# Delaware           87
# Vermont            87
# Maryland           86
# Louisiana          84
# North Dakota       83
# West Virginia      83
# Missouri           82
# Mississippi        81
# New Mexico         81
# Arkansas           81
# Maine              80
# Georgia            80
# Kentucky           80
# Tennessee          80
# North Carolina     80
# Virginia           80
# Indiana            79
# Connecticut        79
# Texas              79
# Ohio               78
# Wisconsin          78
# South Carolina     77
# Colorado           76
# Oklahoma           76
# Oregon             75
# Pennsylvania       74
# Michigan           73
# Washington         73
# Alaska             72
# Massachusetts      72
# New Hampshire      71
# Utah               71
# Wyoming            71
# Iowa               70
# South Dakota       70
# Florida            68
# New Jersey         67
# Hawaii             66
# Arizona            65
# Kansas             64
# Rhode Island       63
# Name: count, dtype: int64

# %%
df['Season'].value_counts()
# Out:
# Season
# Spring    1280
# Winter    1255
# Summer    1231
# Fall       985
# Autumn     299
# Name: count, dtype: int64

# %%
df['Subscription Status'].value_counts()
# Out:
# Subscription Status
# No     3462
# Yes    1588
# Name: count, dtype: int64

# %%
df['Shipping Type'].value_counts()
# Out:
# Shipping Type
# Standard          1213
# Express           1207
# Free Shipping      683
# Next Day Air       656
# Store Pickup       655
# 2-Day Shipping     636
# Name: count, dtype: int64

# %%
df['Discount Applied'].value_counts()
# Out:
# Discount Applied
# No     2789
# Yes    2261
# Name: count, dtype: int64

# %%
df['Previous Purchases'].nunique()
# Out:
# 51

# %%
df['Payment Method'].value_counts()
# Out:
# Payment Method
# Credit Card      954
# Cash             949
# Debit Card       943
# PayPal           939
# Venmo            640
# Bank Transfer    625
# Name: count, dtype: int64

# %%
df['Frequency of Purchases'].value_counts()
# Out:
# Frequency of Purchases
# Monthly           946
# Quarterly         933
# Weekly            894
# Every 3 Months    592
# Annually          581
# Bi-Weekly         556
# Fortnightly       548
# Name: count, dtype: int64
